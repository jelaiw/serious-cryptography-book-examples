# %%
p = random_prime(2^32); p
# Out:
# 831379897

# %%
q = random_prime(2^32); q
# Out:
# 1778218133

# %%
n = p * q
n
# Out:
# 1478374808257072301

# %%
phi = (p - 1)*(q - 1)
phi
# Out:
# 1478374805647474272

# %%
e = random_prime(phi)
e
# Out:
# 574436562577605293

# %%
d = e.inverse_mod(phi)
d
# Out:
# 1028189064502941509

# %%
mod(d*e, phi)
# Out:
# 1
