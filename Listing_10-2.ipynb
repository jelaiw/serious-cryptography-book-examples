# %%
n = 1478374808257072301
e = 574436562577605293

# %%
x = 1234567

# %%
y = power_mod(x, e, n); y
# Out:
# 223333253705409589

# %%
d = 1028189064502941509

# %%
power_mod(y, d, n)
# Out:
# 1234567
