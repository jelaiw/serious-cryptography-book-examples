# %%
openssl speed ecdsap256 rsa4096
# Out:
# Doing 4096 bits private rsa's for 10s: 1604 4096 bits private RSA's in 9.64s
# Doing 4096 bits public rsa's for 10s: 105391 4096 bits public RSA's in 9.91s
# Doing 256 bits sign ecdsa's for 10s: 420677 256 bits ECDSA signs in 9.70s
# Doing 256 bits verify ecdsa's for 10s: 131307 256 bits ECDSA verify in 9.87s
# OpenSSL 1.1.1q  5 Jul 2022
# built on: Wed Jul  6 10:35:35 2022 UTC
# options:bn(64,64) rc4(16x,int) des(int) aes(partial) idea(int) blowfish(ptr)
# ...
