# %%
openssl speed rsa2048
# Out:
# Doing 2048 bits private rsa's for 10s: 14620 2048 bits private RSA's in 9.54s
# Doing 2048 bits public rsa's for 10s: 369736 2048 bits public RSA's in 9.51s
# OpenSSL 1.1.1q  5 Jul 2022
# built on: Wed Jul  6 10:35:35 2022 UTC
# options:bn(64,64) rc4(16x,int) des(int) aes(partial) idea(int) blowfish(ptr)
# ...
