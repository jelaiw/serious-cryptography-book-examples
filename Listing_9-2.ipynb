# %%
p = random_prime(2**64); p
# Out:
# 14694550975385653591

# %%
q = random_prime(2**64); q
# Out:
# 13237331514073829179

# %%
# Generate an RSA modulus from two random prime numbers.
n = p * q; n
# Out:
# 194516642711636837217917938787001931789

# %%
# Factor it "instantaneously".
factor(n)
# Out:
# 13237331514073829179 * 14694550975385653591
