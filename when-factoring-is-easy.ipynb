# %%
# Note, this is a 1024-bit number chosen to be easy to factor.
N = 2**800 * 641 * 6700417 * 167773885276849215533569 * 37414057161322375957408148834323969
N
# Out:
# 

# %%
factor(N)
# Out:
# 2^800 * 641 * 6700417 * 167773885276849215533569 * 37414057161322375957408148834323969
